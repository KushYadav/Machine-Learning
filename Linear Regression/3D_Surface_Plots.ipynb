# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
a=np.arange(-4,4,0.02)
b=a

a,b=np.meshgrid(a,b)
# print(a)
# print(b)

# %%
m=a.shape[0]
n=a.shape[1]
print(m,n)

for i in range(m):
    for j in range(n):
        pass
#         print("(%d,%d)"%(b[i,j],a[i,j]),end=' ')
#       print()
# Out:
# 400 400

# %%
fig=plt.figure()
axes=fig.gca(projection='3d')
axes.plot_surface(a,b,a**2+b**2,cmap='coolwarm')
plt.show()

# %%
fig=plt.figure()
axes=fig.gca(projection='3d')
axes.contour(a,b,a**2+b**2,cmap='rainbow')
plt.show()

# %%
plt.contour(a,b,a**2+b**2)
plt.show()
# Along the circle, the error is constant.
